# %% [markdown]
# # Brain Mode Cluster Analysis

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# In order to have a functioning directory path, create a shortcut of the "Data and Preparation" folder in My Drive. Go to *Complex Systems Project* shared drive, Press the three dots next to *Data and Preparation* > *Organize* > *Add a shortcut* > *All locations* > *My Drive*

# %%
# Installing required packages

# %pip install PyEDFlib
# %pip install mne
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 60.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for PyEDFlib: filename=pyedflib-0.1.40-cp311-cp311-linux_x86_64.whl size=2734976 sha256=f0d119f90326aff4920e7c8a167425fa413066a92a0e832847252a5f618b37db
#   Stored in directory: /root/.cache/pip/wheels/8d/df/d6/88ce619bde055ebffebae5380645802eca490817853b60b45b
# Successfully built PyEDFlib
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 90.6 MB/s eta 0:00:00
# ...

# %%
# Setting data path and importing libraries
ad_data_path = '/content/drive/My Drive/Data and Preparation/Antidepressant response/DD_Files/'
k_data_path = '/content/drive/My Drive/Data and Preparation/Ketamine Study/'
import pyedflib
import numpy as np
import pandas as pd
import mne
