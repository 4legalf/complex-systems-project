# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install PyEDFlib
# %pip install mne
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 50.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for PyEDFlib: filename=pyedflib-0.1.40-cp311-cp311-linux_x86_64.whl size=2734987 sha256=180a9dde81cf81917b619f2cc38deaacb84563bab3008189656590bb6eea577c
#   Stored in directory: /root/.cache/pip/wheels/8d/df/d6/88ce619bde055ebffebae5380645802eca490817853b60b45b
# Successfully built PyEDFlib
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 84.8 MB/s eta 0:00:00
# ...

# %%
data_path = '/content/drive/My Drive/Data and Preparation/Antidepressant response/DD_Files/'

# %%
import pyedflib
import numpy as np
import pandas as pd
import mne

# %%
def edf_to_DF(edf_path):
    f = pyedflib.EdfReader(edf_path)
    n = f.signals_in_file
    signal_labels = f.getSignalLabels()
    sigbufs = np.zeros((n, f.getNSamples()[0]))
    for i in np.arange(n):
        sigbufs[i, :] = f.readSignal(i)
    DF = pd.DataFrame(sigbufs.T, columns=signal_labels)
    return DF

# %%
def edf_to_arr(edf_path):
    f = pyedflib.EdfReader(edf_path)
    n = f.signals_in_file
    signal_labels = f.getSignalLabels()
    sigbufs = np.zeros((n, f.getNSamples()[0]))
    for i in np.arange(n):
        sigbufs[i, :] = f.readSignal(i)

    return sigbufs

# %%
test_arr = edf_to_arr(data_path + 'DD01S1EC-edf.edf')

# %%
test_DF = edf_to_DF(data_path + 'DD01S1EC-edf.edf')
test_DF
# Out:
#              Fp1       Fp2        F3        F4        C3         C4  \
# 0      -8.213714  2.331583  2.370422 -3.578396  1.118765   3.363036
# 1     -12.092076 -1.937726 -0.369733 -6.237334  0.898827   9.549223
# 2     -14.809792 -5.351154 -1.803623 -7.218089 -0.315319  10.606499
# 3     -14.939731 -5.946989 -1.972536 -6.043907 -1.751647   7.794595
# 4     -12.873915 -3.790874 -1.007852 -3.357726 -2.196011   2.013323
# ...          ...       ...       ...       ...       ...        ...
# 95739  -3.868451 -7.603208  0.722575  3.651953 -7.799935  12.586078
# 95740  -3.868451 -7.603208  0.722575  3.651953 -7.799935  12.586078
# 95741  -3.868451 -7.603208  0.722575  3.651953 -7.799935  12.586078
# 95742  -3.868451 -7.603208  0.722575  3.651953 -7.799935  12.586078
# 95743  -3.868451 -7.603208  0.722575  3.651953 -7.799935  12.586078
#
#               P3         P4        O1         O2  ...       FC6       CP5  \
# 0      -6.595415 -11.069405 -6.495283  -9.686158  ... -2.898806  7.343748
# ...

# %%
test_file = pyedflib.EdfReader(data_path + 'DD02S1EC-edf.edf')

# %%
test_file.getHeader()
# Out:
# {'technician': '',
#  'recording_additional': '',
#  'patientname': 'X',
#  'patient_additional': '',
#  'patientcode': '',
#  'equipment': '',
#  'admincode': '',
#  'sex': '',
#  'startdate': datetime.datetime(2008, 8, 20, 14, 8, 11),
#  'birthdate': '01 jan 0000',
#  'gender': ''}

# %%
test_file.getSignalHeaders()[0]
# Out:
# {'label': 'Fp1',
#  'dimension': 'uV',
#  'sample_frequency': 512.0,
#  'physical_max': 148.638,
#  'physical_min': -148.638,
#  'digital_max': 30000,
#  'digital_min': -30001,
#  'prefilter': '',
#  'transducer': 'AgAgCl electrode'}

# %%
count(test_file.getSignalLabels())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-23ba30a2b88e> in <cell line: 0>()
# ----> 1 count(test_file.getSignalLabels())
#
# NameError: name 'count' is not defined

# %%
mne_test = mne.io.read_raw_edf(data_path + 'DD01S1EC-edf.edf')
# Out:
# Extracting EDF parameters from /content/drive/My Drive/Data and Preparation/Antidepressant response/DD_Files/DD01S1EC-edf.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
